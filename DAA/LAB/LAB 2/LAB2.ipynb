# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def removeDuplicates(Array):
    for i in Array:
        if Array.count(i)>1:
            Array.remove(i)
    
A = [2, 7, 7, 11, 24, 24, 24, 29, 36, 36]
removeDuplicates(A)
print(A)
# Out:
# [2, 7, 11, 24, 29, 36]
